# %% [markdown]
# ## Lab 06

# %% [markdown]
# ### Zadanie 1 - Regexy

# %% [markdown]
# Przejdź 15 zadań ze strony http://regexone.com/

# %%
#1 
".*" # a, ab, abc

#1.5
"\d+"

#2
".*\."

#3
"[cmf]an"

#4
"[^b]og"

#5
"[A-Z][a-z]+"

#6
"waz{2,}up"

#7
"a+b*c+"

#8
"\d+ files? found\?"

#9
"\d+\.\s+\w+"  #\s+

#10
"^Mission"

#11
"^([a-z0-9_]*).pdf$"

#12
"([A-Z][a-z]{2} (\d{1,4}))"

#13
"(\d+)x(\d+)"

#14
"I love (cats|dogs)"

#15
"\W" #.* etc
# Out:
# '\\W'

# %% [markdown]
# ### Zadanie 2 - Regexy

# %% [markdown]
# _Atoms_
#
# Napisz program, który (używając wyrażeń regularnych) przefiltruje plik atoms.log tak by pozostały jedynie linie dot. bezproblemowego przebiegu eksperymentu.
# czyli np. powinny zostać odrzucone takie linie jak
# ```
# RUN 000039 COMPLETED. OUTPUT IN FILE yttrium.dat. 1 UNDERFLOW WARNING.
# ```
# czy
# ```
# RUN 000058 COMPLETED. OUTPUT IN FILE cerium.dat. ALGORITHM DID NOT CONVERGE AFTER 100000 ITERATIONS.
# ```
# można jedynie założyć, że każda linijka pasuje do poniższego schematu
# ```
# RUN [[NUMER Z DOKŁADNIE 6 CYFR]] COMPLETED. OUTPUT IN FILE [[NAZWA]].dat. [[COKOLWIEK]]
# ```

# %%
import re

pattern = "RUN \d{6} COMPLETED. OUTPUT IN FILE [A-Za-z0-9_]+\.dat\.$"

with open('atoms.log') as atoms:
    for line in atoms:
        if re.match(pattern, line):
            print(line)
# Out:
# RUN 000001 COMPLETED. OUTPUT IN FILE hydrogen.dat.
#
# RUN 000002 COMPLETED. OUTPUT IN FILE helium.dat.
#
# RUN 000003 COMPLETED. OUTPUT IN FILE lithium.dat.
#
# RUN 000004 COMPLETED. OUTPUT IN FILE beryllium.dat.
#
# RUN 000005 COMPLETED. OUTPUT IN FILE boron.dat.
#
# RUN 000006 COMPLETED. OUTPUT IN FILE carbon.dat.
#
# RUN 000007 COMPLETED. OUTPUT IN FILE nitogen.dat.
#
# RUN 000008 COMPLETED. OUTPUT IN FILE oxygen.dat.
#
# RUN 000009 COMPLETED. OUTPUT IN FILE fluorine.dat.
#
# RUN 000010 COMPLETED. OUTPUT IN FILE neon.dat.
#
# RUN 000011 COMPLETED. OUTPUT IN FILE sodium.dat.
#
# RUN 000012 COMPLETED. OUTPUT IN FILE magnesium.dat.
#
# RUN 000013 COMPLETED. OUTPUT IN FILE aluminium.dat.
#
# RUN 000014 COMPLETED. OUTPUT IN FILE silicon.dat.
#
# RUN 000015 COMPLETED. OUTPUT IN FILE phosphorus.dat.
#
# RUN 000016 COMPLETED. OUTPUT IN FILE sulphur.dat.
#
# RUN 000017 COMPLETED. OUTPUT IN FILE chlorine.dat.
#
# RUN 000018 COMPLETED. OUTPUT IN FILE argon.dat.
#
# RUN 000019 COMPLETED. OUTPUT IN FILE potassium.dat.
#
# RUN 000020 COMPLETED. OUTPUT IN FILE calcium.dat.
#
# RUN 000021 COMPLETED. OUTPUT IN FILE scandium.dat.
#
# RUN 000022 COMPLETED. OUTPUT IN FILE titanium.dat.
#
# RUN 000023 COMPLETED. OUTPUT IN FILE vanadium.dat.
#
# RUN 000024 COMPLETED. OUTPUT IN FILE chromium.dat.
#
# RUN 000025 COMPLETED. OUTPUT IN FILE manganese.dat.
#
# RUN 000026 COMPLETED. OUTPUT IN FILE iron.dat.
#
# RUN 000027 COMPLETED. OUTPUT IN FILE cobalt.dat.
#
# RUN 000028 COMPLETED. OUTPUT IN FILE nickel.dat.
#
# RUN 000029 COMPLETED. OUTPUT IN FILE copper.dat.
#
# RUN 000030 COMPLETED. OUTPUT IN FILE zinc.dat.
#
# RUN 000031 COMPLETED. OUTPUT IN FILE gallium.dat.
#
# RUN 000032 COMPLETED. OUTPUT IN FILE germanium.dat.
#
# RUN 000033 COMPLETED. OUTPUT IN FILE arsenic.dat.
#
# RUN 000034 COMPLETED. OUTPUT IN FILE selenium.dat.
#
# RUN 000035 COMPLETED. OUTPUT IN FILE bromine.dat.
#
# RUN 000036 COMPLETED. OUTPUT IN FILE krypton.dat.
#
# RUN 000037 COMPLETED. OUTPUT IN FILE rubidium.dat.
#
# RUN 000038 COMPLETED. OUTPUT IN FILE strontium.dat.
#
# RUN 000049 COMPLETED. OUTPUT IN FILE indium.dat.
#
# RUN 000050 COMPLETED. OUTPUT IN FILE tin.dat.
#
# RUN 000051 COMPLETED. OUTPUT IN FILE antimony.dat.
#
# RUN 000052 COMPLETED. OUTPUT IN FILE tellurium.dat.
#
# RUN 000053 COMPLETED. OUTPUT IN FILE iodine.dat.
#
# RUN 000054 COMPLETED. OUTPUT IN FILE xenon.dat.
#
# RUN 000055 COMPLETED. OUTPUT IN FILE caesium.dat.
#
# RUN 000056 COMPLETED. OUTPUT IN FILE barium.dat.
#
# RUN 000081 COMPLETED. OUTPUT IN FILE thallium.dat.
#
# RUN 000082 COMPLETED. OUTPUT IN FILE lead.dat.
#
# RUN 000083 COMPLETED. OUTPUT IN FILE bismuth.dat.
#
# RUN 000084 COMPLETED. OUTPUT IN FILE polonium.dat.
#
# RUN 000085 COMPLETED. OUTPUT IN FILE astatine.dat.
#
# RUN 000086 COMPLETED. OUTPUT IN FILE radon.dat.
#
# RUN 000087 COMPLETED. OUTPUT IN FILE francium.dat.
#
# RUN 000088 COMPLETED. OUTPUT IN FILE radium.dat.

# %% [markdown]
# ### Zadanie 3 - Regexy

# %% [markdown]
# _Messages_
#
# Napisz program który wypisze linie z logu systemowego "messages.txt" które zawierają informacje o nieprawidłowej nazwie użytkownika (invalid user)

# %%
months = {
    "Jan": "stycznia",
    "Feb": "lutego",
    "Mar": "marca",
    "Apr": "kwietnia",
    "May": "maja",
    "Jun": "czerwca",
    "Jul": "lipca",
    "Aug": "sierpnia",
    "Sep": "września",
    "Oct": "października",
    "Nov": "listopada",
    "Dec": "grudnia"
}

pattern = "([A-Z][a-z]{2}) (\d{2}) (\d{2}:\d{2}):\d{2} .*: Invalid user (.+) from (\d{3}\.\d{3}\.\d{3}\.\d{3})"

with open('messages.txt') as messages:
    for line in messages:
        match = re.search(pattern, line)
        if match:
            print(f"Niepoprawna nazwa użytkownika: \"{match.group(4)}\", połączenie z {match.group(5)} nawiązano {match.group(2)} {months[match.group(1)]} o godz. {match.group(3)}")
# Out:
# Niepoprawna nazwa użytkownika: "uw", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:15
# Niepoprawna nazwa użytkownika: "hostland", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:15
# Niepoprawna nazwa użytkownika: "shellland", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:15
# Niepoprawna nazwa użytkownika: "au", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:15
# Niepoprawna nazwa użytkownika: "usa", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:15
# Niepoprawna nazwa użytkownika: "sua", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:15
# Niepoprawna nazwa użytkownika: "excces", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:15
# Niepoprawna nazwa użytkownika: "tw", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:15
# Niepoprawna nazwa użytkownika: "fragvid", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:15
# Niepoprawna nazwa użytkownika: "user", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:15
# Niepoprawna nazwa użytkownika: "shaer", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:15
# Niepoprawna nazwa użytkownika: "gun", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:15
# Niepoprawna nazwa użytkownika: "aa", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:15
# Niepoprawna nazwa użytkownika: "asdf", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:15
# Niepoprawna nazwa użytkownika: "abcd", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:15
# Niepoprawna nazwa użytkownika: "guv", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:15
# Niepoprawna nazwa użytkownika: "sn", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:15
# Niepoprawna nazwa użytkownika: "hk", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:16
# Niepoprawna nazwa użytkownika: "connect", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:16
# Niepoprawna nazwa użytkownika: "host", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:16
# Niepoprawna nazwa użytkownika: "box", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:16
# Niepoprawna nazwa użytkownika: "psy", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:16
# Niepoprawna nazwa użytkownika: "wap", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:16
# Niepoprawna nazwa użytkownika: "ccc", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:16
# Niepoprawna nazwa użytkownika: "domain", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:16
# Niepoprawna nazwa użytkownika: "newbitnet", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:16
# Niepoprawna nazwa użytkownika: "mailadm", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:16
# Niepoprawna nazwa użytkownika: "tcf", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:16
# Niepoprawna nazwa użytkownika: "rk", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:16
# Niepoprawna nazwa użytkownika: "direccion", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:16
# Niepoprawna nazwa użytkownika: "karin", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:16
# Niepoprawna nazwa użytkownika: "jrico", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:16
# Niepoprawna nazwa użytkownika: "niit", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:16
# Niepoprawna nazwa użytkownika: "sysconfig/rk", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:16
# Niepoprawna nazwa użytkownika: "ldapuser", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:16
# Niepoprawna nazwa użytkownika: "syscp", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:16
# Niepoprawna nazwa użytkownika: "entinux", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:16
# Niepoprawna nazwa użytkownika: "nexusmailer", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:16
# Niepoprawna nazwa użytkownika: "warpuser", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:16
# Niepoprawna nazwa użytkownika: "fwadmin", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:16
# Niepoprawna nazwa użytkownika: "php12", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:16
# Niepoprawna nazwa użytkownika: "ipbb12", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:16
# Niepoprawna nazwa użytkownika: "film", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:16
# Niepoprawna nazwa użytkownika: "video", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:17
# Niepoprawna nazwa użytkownika: "dvd", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:17
# Niepoprawna nazwa użytkownika: "admin", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:17
# Niepoprawna nazwa użytkownika: "webmaster", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:17
# Niepoprawna nazwa użytkownika: "test", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:17
# Niepoprawna nazwa użytkownika: "admin", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:17
# Niepoprawna nazwa użytkownika: "test", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:17
# Niepoprawna nazwa użytkownika: "master", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:17
# Niepoprawna nazwa użytkownika: "localhost", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:17
# Niepoprawna nazwa użytkownika: "localdomain", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:17
# Niepoprawna nazwa użytkownika: "test", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:17
# Niepoprawna nazwa użytkownika: "test", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:17
# Niepoprawna nazwa użytkownika: "xhost", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:17
# Niepoprawna nazwa użytkownika: "freehost", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:17
# Niepoprawna nazwa użytkownika: "freeftp", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:17
# Niepoprawna nazwa użytkownika: "commands", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:17
# Niepoprawna nazwa użytkownika: "command", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:17
# Niepoprawna nazwa użytkownika: "ls", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:17
# Niepoprawna nazwa użytkownika: "lx", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:17
# Niepoprawna nazwa użytkownika: "uname", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:17
# Niepoprawna nazwa użytkownika: "topic", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:17
# Niepoprawna nazwa użytkownika: "forum", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:17
# Niepoprawna nazwa użytkownika: "micros", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:17
# Niepoprawna nazwa użytkownika: "quantadl", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:17
# Niepoprawna nazwa użytkownika: "yxc", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:17
# Niepoprawna nazwa użytkownika: "yuxxx", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:17
# Niepoprawna nazwa użytkownika: "unity-prima", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:18
# Niepoprawna nazwa użytkownika: "huang", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:18
# Niepoprawna nazwa użytkownika: "tmpFtp", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:18
# Niepoprawna nazwa użytkownika: "win1", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:18
# Niepoprawna nazwa użytkownika: "sas50001", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:18
# Niepoprawna nazwa użytkownika: "sakaimusen", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:18
# Niepoprawna nazwa użytkownika: "repeater", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:18
# Niepoprawna nazwa użytkownika: "dropoff", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:18
# Niepoprawna nazwa użytkownika: "abidch", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:18
# Niepoprawna nazwa użytkownika: "mailsyd", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:18
# Niepoprawna nazwa użytkownika: "rpcuser", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:18
# Niepoprawna nazwa użytkownika: "named", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:18
# Niepoprawna nazwa użytkownika: "squid", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:18
# Niepoprawna nazwa użytkownika: "xfs", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:18
# Niepoprawna nazwa użytkownika: "windows", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:18
# Niepoprawna nazwa użytkownika: "start", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:18
# Niepoprawna nazwa użytkownika: "tester", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:18
# Niepoprawna nazwa użytkownika: "testing", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:18
# Niepoprawna nazwa użytkownika: "admin", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:18
# Niepoprawna nazwa użytkownika: "test", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:18
# Niepoprawna nazwa użytkownika: "test", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:18
# Niepoprawna nazwa użytkownika: "admin", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:18
# Niepoprawna nazwa użytkownika: "test", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:18
# Niepoprawna nazwa użytkownika: "admin", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:18
# Niepoprawna nazwa użytkownika: "webmaster", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:19
# Niepoprawna nazwa użytkownika: "webmaster", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:19
# Niepoprawna nazwa użytkownika: "art02", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:19
# Niepoprawna nazwa użytkownika: "nevada", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:19
# Niepoprawna nazwa użytkownika: "qwert", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:19
# Niepoprawna nazwa użytkownika: "lkjh", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:19
# Niepoprawna nazwa użytkownika: "uptime", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:19
# Niepoprawna nazwa użytkownika: "members", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:19
# Niepoprawna nazwa użytkownika: "member", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:19
# Niepoprawna nazwa użytkownika: "nl", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:19
# Niepoprawna nazwa użytkownika: "gov", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:19
# Niepoprawna nazwa użytkownika: "conf", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:19
# Niepoprawna nazwa użytkownika: "police", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:19
# Niepoprawna nazwa użytkownika: "interpol", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:19
# Niepoprawna nazwa użytkownika: "login", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:19
# Niepoprawna nazwa użytkownika: "phone", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:19
# Niepoprawna nazwa użytkownika: "company", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:19
# Niepoprawna nazwa użytkownika: "pat", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:19
# Niepoprawna nazwa użytkownika: "loredana", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:19
# Niepoprawna nazwa użytkownika: "peter", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:19
# Niepoprawna nazwa użytkownika: "kiss", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:19
# Niepoprawna nazwa użytkownika: "passfile", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:19
# Niepoprawna nazwa użytkownika: "pass", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:19
# Niepoprawna nazwa użytkownika: "file", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:19
# Niepoprawna nazwa użytkownika: "it", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:19
# Niepoprawna nazwa użytkownika: "next", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:19
# Niepoprawna nazwa użytkownika: "down", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:20
# Niepoprawna nazwa użytkownika: "send", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:20
# Niepoprawna nazwa użytkownika: "sendmail", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:20
# Niepoprawna nazwa użytkownika: "mailsend", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:20
# Niepoprawna nazwa użytkownika: "eby", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:20
# Niepoprawna nazwa użytkownika: "jail", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:20
# Niepoprawna nazwa użytkownika: "fuck", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:20
# Niepoprawna nazwa użytkownika: "webmaster", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:20
# Niepoprawna nazwa użytkownika: "admin", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:20
# Niepoprawna nazwa użytkownika: "webadmin", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:20
# Niepoprawna nazwa użytkownika: "ftpuser", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:20
# Niepoprawna nazwa użytkownika: "testuser", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:20
# Niepoprawna nazwa użytkownika: "testuser", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:20
# Niepoprawna nazwa użytkownika: "test", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:20
# Niepoprawna nazwa użytkownika: "guestuser", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:20
# Niepoprawna nazwa użytkownika: "test01", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:20
# Niepoprawna nazwa użytkownika: "test2", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:20
# Niepoprawna nazwa użytkownika: "test3", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:20
# Niepoprawna nazwa użytkownika: "test4", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:20
# Niepoprawna nazwa użytkownika: "test5", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:20
# Niepoprawna nazwa użytkownika: "test6", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:20
# Niepoprawna nazwa użytkownika: "test7", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:20
# Niepoprawna nazwa użytkownika: "test8", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:20
# Niepoprawna nazwa użytkownika: "test9", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:20
# Niepoprawna nazwa użytkownika: "test10", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:21
# Niepoprawna nazwa użytkownika: "user1", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:21
# Niepoprawna nazwa użytkownika: "user2", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:21
# Niepoprawna nazwa użytkownika: "user3", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:21
# Niepoprawna nazwa użytkownika: "user4", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:21
# Niepoprawna nazwa użytkownika: "user5", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:21
# Niepoprawna nazwa użytkownika: "user6", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:21
# Niepoprawna nazwa użytkownika: "user7", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:21
# Niepoprawna nazwa użytkownika: "user8", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:21
# Niepoprawna nazwa użytkownika: "user9", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:21
# Niepoprawna nazwa użytkownika: "user10", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:21
# Niepoprawna nazwa użytkownika: "simon", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:21
# Niepoprawna nazwa użytkownika: "david", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:21
# Niepoprawna nazwa użytkownika: "monica", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:21
# Niepoprawna nazwa użytkownika: "sql", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:21
# Niepoprawna nazwa użytkownika: "sybase", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:21
# Niepoprawna nazwa użytkownika: "informix", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:21
# Niepoprawna nazwa użytkownika: "shell", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:22
# Niepoprawna nazwa użytkownika: "noaccess", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:22
# Niepoprawna nazwa użytkownika: "email", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:22
# Niepoprawna nazwa użytkownika: "phone", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:22
# Niepoprawna nazwa użytkownika: "marketing", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:22
# Niepoprawna nazwa użytkownika: "http", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:22
# Niepoprawna nazwa użytkownika: "httpd", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:23
# Niepoprawna nazwa użytkownika: "mike", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:23
# Niepoprawna nazwa użytkownika: "michael", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:23
# Niepoprawna nazwa użytkownika: "john", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:23
# Niepoprawna nazwa użytkownika: "andrea", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:23
# Niepoprawna nazwa użytkownika: "andrew", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:23
# Niepoprawna nazwa użytkownika: "amanda", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:23
# Niepoprawna nazwa użytkownika: "barbara", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:23
# Niepoprawna nazwa użytkownika: "jack", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:23
# Niepoprawna nazwa użytkownika: "operator", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:23
# Niepoprawna nazwa użytkownika: "operador", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:23
# Niepoprawna nazwa użytkownika: "grafik", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:23
# Niepoprawna nazwa użytkownika: "usuario", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:23
# Niepoprawna nazwa użytkownika: "norma", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:23
# Niepoprawna nazwa użytkownika: "robert", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:23
# Niepoprawna nazwa użytkownika: "roberto", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:23
# Niepoprawna nazwa użytkownika: "bobby", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:23
# Niepoprawna nazwa użytkownika: "cesar", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:23
# Niepoprawna nazwa użytkownika: "daniel", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:23
# Niepoprawna nazwa użytkownika: "jim", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:23
# Niepoprawna nazwa użytkownika: "jimmy", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:23
# Niepoprawna nazwa użytkownika: "lee", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:23
# Niepoprawna nazwa użytkownika: "matt", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:23
# Niepoprawna nazwa użytkownika: "paul", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:23
# Niepoprawna nazwa użytkownika: "peter", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:23
# Niepoprawna nazwa użytkownika: "sean", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:23
# Niepoprawna nazwa użytkownika: "steve", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:24
# Niepoprawna nazwa użytkownika: "steven", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:24
# Niepoprawna nazwa użytkownika: "temp", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:24
# Niepoprawna nazwa użytkownika: "tim", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:24
# Niepoprawna nazwa użytkownika: "tom", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:24
# Niepoprawna nazwa użytkownika: "samba", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:24
# Niepoprawna nazwa użytkownika: "apple", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:24
# Niepoprawna nazwa użytkownika: "master", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:24
# Niepoprawna nazwa użytkownika: "manager", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:24
# Niepoprawna nazwa użytkownika: "xxx", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:24
# Niepoprawna nazwa użytkownika: "jerry", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:24
# Niepoprawna nazwa użytkownika: "jesus", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:24
# Niepoprawna nazwa użytkownika: "zeus", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:24
# Niepoprawna nazwa użytkownika: "god", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:24
# Niepoprawna nazwa użytkownika: "erica", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:24
# Niepoprawna nazwa użytkownika: "eric", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:24
# Niepoprawna nazwa użytkownika: "alexander", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:24
# Niepoprawna nazwa użytkownika: "webuser", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:24
# Niepoprawna nazwa użytkownika: "xbox", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:24
# Niepoprawna nazwa użytkownika: "ewa", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:24
# Niepoprawna nazwa użytkownika: "postmaster", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:24
# Niepoprawna nazwa użytkownika: "brenda", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:24
# Niepoprawna nazwa użytkownika: "berlin", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:25
# Niepoprawna nazwa użytkownika: "deutsh", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:25
# Niepoprawna nazwa użytkownika: "jorge", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:25
# Niepoprawna nazwa użytkownika: "george", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:25
# Niepoprawna nazwa użytkownika: "apagar", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:25
# Niepoprawna nazwa użytkownika: "apache", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:25
# Niepoprawna nazwa użytkownika: "michele", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:25
# Niepoprawna nazwa użytkownika: "veronica", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:25
# Niepoprawna nazwa użytkownika: "elena", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:25
# Niepoprawna nazwa użytkownika: "diana", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:25
# Niepoprawna nazwa użytkownika: "olivia", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:25
# Niepoprawna nazwa użytkownika: "dina", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:25
# Niepoprawna nazwa użytkownika: "eduard", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:25
# Niepoprawna nazwa użytkownika: "eduardo", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:25
# Niepoprawna nazwa użytkownika: "edoardo", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:25
# Niepoprawna nazwa użytkownika: "server", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:25
# Niepoprawna nazwa użytkownika: "angel", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:25
# Niepoprawna nazwa użytkownika: "cristina", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:25
# Niepoprawna nazwa użytkownika: "christine", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:25
# Niepoprawna nazwa użytkownika: "testing", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:25
# Niepoprawna nazwa użytkownika: "teacher", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:25
# Niepoprawna nazwa użytkownika: "student", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:25
# Niepoprawna nazwa użytkownika: "support", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:25
# Niepoprawna nazwa użytkownika: "soporte", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:25
# Niepoprawna nazwa użytkownika: "training", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:25
# Niepoprawna nazwa użytkownika: "max", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:25
# Niepoprawna nazwa użytkownika: "alex", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:26
# Niepoprawna nazwa użytkownika: "albert", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:26
# Niepoprawna nazwa użytkownika: "alberto", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:26
# Niepoprawna nazwa użytkownika: "frank", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:26
# Niepoprawna nazwa użytkownika: "guest", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:26
# Niepoprawna nazwa użytkownika: "oracle", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:26
# Niepoprawna nazwa użytkownika: "salva", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:26
# Niepoprawna nazwa użytkownika: "sales", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:26
# Niepoprawna nazwa użytkownika: "service", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:26
# Niepoprawna nazwa użytkownika: "office", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:26
# Niepoprawna nazwa użytkownika: "public", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:26
# Niepoprawna nazwa użytkownika: "publico", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:26
# Niepoprawna nazwa użytkownika: "wwwadmin", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:26
# Niepoprawna nazwa użytkownika: "mark", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:26
# Niepoprawna nazwa użytkownika: "dave", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:26
# Niepoprawna nazwa użytkownika: "kevin", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:26
# Niepoprawna nazwa użytkownika: "sam", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:26
# Niepoprawna nazwa użytkownika: "lisa", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:26
# Niepoprawna nazwa użytkownika: "vincent", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:26
# Niepoprawna nazwa użytkownika: "tony", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:26
# Niepoprawna nazwa użytkownika: "helen", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:26
# Niepoprawna nazwa użytkownika: "laura", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:26
# Niepoprawna nazwa użytkownika: "setup", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:26
# Niepoprawna nazwa użytkownika: "install", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:26
# Niepoprawna nazwa użytkownika: "maintain", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:26
# Niepoprawna nazwa użytkownika: "syslib", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:27
# Niepoprawna nazwa użytkownika: "sysop", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:27
# Niepoprawna nazwa użytkownika: "sysadmin", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:27
# Niepoprawna nazwa użytkownika: "software", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:27
# Niepoprawna nazwa użytkownika: "default", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:27
# Niepoprawna nazwa użytkownika: "sound", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:27
# Niepoprawna nazwa użytkownika: "studio", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:27
# Niepoprawna nazwa użytkownika: "film", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:27
# Niepoprawna nazwa użytkownika: "user", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:27
# Niepoprawna nazwa użytkownika: "custom", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:27
# Niepoprawna nazwa użytkownika: "sysadm", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:27
# Niepoprawna nazwa użytkownika: "telnet", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:27
# Niepoprawna nazwa użytkownika: "telnets", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:27
# Niepoprawna nazwa użytkownika: "socket", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:27
# Niepoprawna nazwa użytkownika: "rocky", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:27
# Niepoprawna nazwa użytkownika: "victor", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:27
# Niepoprawna nazwa użytkownika: "maria", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:27
# Niepoprawna nazwa użytkownika: "debug", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:27
# Niepoprawna nazwa użytkownika: "tecnico", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:27
# Niepoprawna nazwa użytkownika: "security", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:27
# Niepoprawna nazwa użytkownika: "recovery", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:27
# Niepoprawna nazwa użytkownika: "device", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:27
# Niepoprawna nazwa użytkownika: "share", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:27
# Niepoprawna nazwa użytkownika: "shares", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:27
# Niepoprawna nazwa użytkownika: "customer", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:27
# Niepoprawna nazwa użytkownika: "anonymous", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:28
# Niepoprawna nazwa użytkownika: "super", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:28
# Niepoprawna nazwa użytkownika: "laptop", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:28
# Niepoprawna nazwa użytkownika: "supervisor", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:28
# Niepoprawna nazwa użytkownika: "superadmin", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:28
# Niepoprawna nazwa użytkownika: "superadmin", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:28
# Niepoprawna nazwa użytkownika: "mp3", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:28
# Niepoprawna nazwa użytkownika: "mp3", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:28
# Niepoprawna nazwa użytkownika: "movie", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:28
# Niepoprawna nazwa użytkownika: "movies", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:28
# Niepoprawna nazwa użytkownika: "update", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:28
# Niepoprawna nazwa użytkownika: "updates", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:28
# Niepoprawna nazwa użytkownika: "telecom", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:28
# Niepoprawna nazwa użytkownika: "echo", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:28
# Niepoprawna nazwa użytkownika: "paola", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:28
# Niepoprawna nazwa użytkownika: "terra", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:28
# Niepoprawna nazwa użytkownika: "troy", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:28
# Niepoprawna nazwa użytkownika: "charlie", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:28
# Niepoprawna nazwa użytkownika: "oliver", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:28
# Niepoprawna nazwa użytkownika: "forum", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:29
# Niepoprawna nazwa użytkownika: "home", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:29
# Niepoprawna nazwa użytkownika: "house", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:29
# Niepoprawna nazwa użytkownika: "mama", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:29
# Niepoprawna nazwa użytkownika: "papa", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:29
# Niepoprawna nazwa użytkownika: "christian", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:29
# Niepoprawna nazwa użytkownika: "hector", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:29
# Niepoprawna nazwa użytkownika: "farmer", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:29
# Niepoprawna nazwa użytkownika: "ping", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:29
# Niepoprawna nazwa użytkownika: "pong", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:29
# Niepoprawna nazwa użytkownika: "record", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:29
# Niepoprawna nazwa użytkownika: "records", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:29
# Niepoprawna nazwa użytkownika: "fernandez", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:29
# Niepoprawna nazwa użytkownika: "jose", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:29
# Niepoprawna nazwa użytkownika: "tiger", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:29
# Niepoprawna nazwa użytkownika: "ronald", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:29
# Niepoprawna nazwa użytkownika: "patrick", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:29
# Niepoprawna nazwa użytkownika: "adrian", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:29
# Niepoprawna nazwa użytkownika: "sandra", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:29
# Niepoprawna nazwa użytkownika: "richard", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:29
# Niepoprawna nazwa użytkownika: "stephen", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:29
# Niepoprawna nazwa użytkownika: "gwen", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:29
# Niepoprawna nazwa użytkownika: "ronald", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:29
# Niepoprawna nazwa użytkownika: "bill", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:29
# Niepoprawna nazwa użytkownika: "aaron", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:30
# Niepoprawna nazwa użytkownika: "benjamin", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:30
# Niepoprawna nazwa użytkownika: "brad", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:30
# Niepoprawna nazwa użytkownika: "caroline", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:30
# Niepoprawna nazwa użytkownika: "carlos", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:30
# Niepoprawna nazwa użytkownika: "video", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:30
# Niepoprawna nazwa użytkownika: "juan", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:30
# Niepoprawna nazwa użytkownika: "judith", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:30
# Niepoprawna nazwa użytkownika: "katherine", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:30
# Niepoprawna nazwa użytkownika: "katy", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:30
# Niepoprawna nazwa użytkownika: "nicolas", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:30
# Niepoprawna nazwa użytkownika: "noname", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:30
# Niepoprawna nazwa użytkownika: "poczta", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:30
# Niepoprawna nazwa użytkownika: "slawek", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:30
# Niepoprawna nazwa użytkownika: "talee", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:30
# Niepoprawna nazwa użytkownika: "tomsko", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:30
# Niepoprawna nazwa użytkownika: "mandrake", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:30
# Niepoprawna nazwa użytkownika: "compushop", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:30
# Niepoprawna nazwa użytkownika: "laboratorio", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:31
# Niepoprawna nazwa użytkownika: "squid", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:31
# Niepoprawna nazwa użytkownika: "clamav", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:31
# Niepoprawna nazwa użytkownika: "cyrus", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:31
# Niepoprawna nazwa użytkownika: "eszter", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:31
# Niepoprawna nazwa użytkownika: "filter", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:31
# Niepoprawna nazwa użytkownika: "ogo", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:31
# Niepoprawna nazwa użytkownika: "named", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:31
# Niepoprawna nazwa użytkownika: "poczta", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:31
# Niepoprawna nazwa użytkownika: "rpcuser", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:31
# Niepoprawna nazwa użytkownika: "nexus", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:31
# Niepoprawna nazwa użytkownika: "nichole", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:31
# Niepoprawna nazwa użytkownika: "cupsys", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:31
# Niepoprawna nazwa użytkownika: "klog", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:31
# Niepoprawna nazwa użytkownika: "amavis", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:31
# Niepoprawna nazwa użytkownika: "swagner", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:31
# Niepoprawna nazwa użytkownika: "mailman", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:31
# Niepoprawna nazwa użytkownika: "icecast", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:31
# Niepoprawna nazwa użytkownika: "macropro", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:31
# Niepoprawna nazwa użytkownika: "magneto", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:31
# Niepoprawna nazwa użytkownika: "proxy", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:31
# Niepoprawna nazwa użytkownika: "message", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:31
# Niepoprawna nazwa użytkownika: "karton", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:31
# Niepoprawna nazwa użytkownika: "emil", połączenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:32

# %% [markdown]
# Przerób program tak, żeby wyświetlał sformatowane komunikaty, tzn.
# ```
# Jun 29 20:18:40 noether sshd[5805]: Invalid user tester from 218.189.194.200
# ```
# powinno zostać przerobione na
# ```
# Niepoprawna nazwa użytkownika: "tester", połaczenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:18
# ```

# %% [markdown]
# ### Zadanie 4 - Collections
# Uzupenij ponizsze funckje korzystajac z zaimporotwanych klas

# %%
from collections import defaultdict

def count_letters(word):
    """ Zwraca slownik gdzie kluczami sa litery, a wartosci ilosc ich wystepowania """
    result = defaultdict(int)

    for letter in word:
        result[letter] += 1
    
    return result 


print(count_letters('aaaaa') == {'a': 5})
print(count_letters('abbccaaaa') == {'a': 5, 'b': 2, 'c': 2})
print(count_letters('abc') == {'a': 1, 'b': 1, 'c': 1})
# Out:
# True
# True
# True

# %%
def group_words_by_first_letter(text):
    """ Dzieli tekst po spacjach i zwraca slownik gdzie kluczami sa pierwsze litery, a wartosciami listy slow zaczynajacych sie na te litery"""
    result = defaultdict(list)

    for word in text.split():
        result[word[0]].append(word)
    
    return result 

print(group_words_by_first_letter("ala ma kota") == {'a': ['ala'], 'm': ['ma'], 'k': ['kota']})
print(group_words_by_first_letter("ala ma kota ala ma psa") == {'a': ['ala', 'ala'], 'm': ['ma', 'ma'], 'k': ['kota'], 'p': ['psa']})   
print(group_words_by_first_letter("ala ma kota ale marysia ma konia") == {'a': ['ala', 'ale'], 'm': ['ma', 'marysia', 'ma'], 'k': ['kota', 'konia']})
# Out:
# True
# True
# True

# %% [markdown]
# ### Zadanie 5 - Klasy
# Uzupełnij brakujące metody poniższej klasy.

# %%
class FrozenDictionary(object):
    """
    Odpowiednik frozenset dla zbiorów, czyli słownik, który nie jest modyfikowalny,
    a dzięki temu może być np. elementem zbiorów, albo kluczem w innym słowniku.
    """
    
    def __init__(self, dictionary):
        """Tworzy nowy zamrożony słownik z podanego słownika"""
        self.dict = dictionary.copy()
    
    def __hash__(self):
        """Zwraca hasz słownika (int)"""
        return hash(frozenset(self.dict.items()))
    
    def __eq__(self, d):
        """Porównuje nasz słownik z zamrożonym słownikiem d"""
        return self.dict == d
    
    def __repr__(self):
        """Zwraca reprezentację naszego słownika jako string"""
        return self.dict.__repr__()
        
dicts = [FrozenDictionary({'ala': 4}), 
         FrozenDictionary({'ala': 1, 'jacek': 0}),
         FrozenDictionary({'ala': 4}), 
         FrozenDictionary({'ala': 2}), 
         FrozenDictionary({'jacek': 0, 'ala': 1})]

s = set(dicts)
print(dicts[0] == dicts[2])
print(dicts[0] != dicts[3])
print(len(s) == 3)
for d in dicts:
    print(d in s)

# Powinno wyświetlić coś w stylu set([{'ala': 4}, {'ala': 1, 'jacek': 0}, {'ala': 2}])
print(s)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# {{'ala': 4}, {'ala': 2}, {'ala': 1, 'jacek': 0}}

# %% [markdown]
# ### Zadanie 6 - Bag of Words
# Napisz klasę "Bag of words", która będzie "workiem słów" z zadanego dokumentu. Oznacza to, że ma w sobie przechowywać informacje o tym ile razy każde słowo wystąpiło w dokumencie. Dodatkowo ma udostępniać następującą funkcjonalność:
# * Można utworzyć go na dwa sposoby:
# ```
# bow = BagOfWords("ala ma kota ala ma ala")
# bow = BagOfWords(open("plik.txt"))
# ```
# * Możliwość wyświetlania go po prostu pisząc print(bow) (kolejność taka sama jak przy przeglądaniu forem)
# ```
# ala:3, ma:2, kota:1
# ```
# * Sprawdzanie czy jakieś słowo należy do naszego worka pisząc
# ```
# if 'ala' in bow:
#     ...
# ```
# * Przeglądanie słów w worku od najczęściej do najrzadziej występującego, czyli
# ```
# for word in bow:
#   print(word)
# ```
#     powinniśmy zobaczyć
# ```
# ala
# ma
# kota
# ```
# * Możliwość dodawania dwóch worków, pisząc
# ```
# bow1 = BagOfWords("ala ma kota ala ma ala")
# bow2 = BagOfWords("tomek tez ma kota")
# bow3 = bow1 + bow2
# print('tomek' in bow1) # False
# print('tomek' in bow3) # True
# print('ala' in bow3) # True
# print(bow3) # ala:3, ma:3, kota:2, tez:1, tomek:1
#     ```
# * Odczytywanie częstości wystąpień słów poprzez nawiasy kwadratowe
# ```
# print(bow1["ala"]) # 3
# print(bow3["ala"]) # 3
# ```
# * Aktualizację cześtości wystąpień
# ```
# bow3['tomek'] = 10
# for el in bow3:
#     print el
# ```
#     powinno wyświetlić najpierw `tomek`

# %%
from collections import defaultdict
import operator

class BagOfWords:
    def __init__(self, text):
        if isinstance(text, dict):
            self.dict = text.copy()
            return 

        self.dict = defaultdict(int)

        if isinstance(text, str):
            self.add_text_to_bag(text)
        else:
            with text as doc:
                for line in doc:
                    self.add_text_to_bag(line)

    def add_text_to_bag(self, text):
        for word in text.split():
                self.dict[word] += 1

    def get_sorted_dict(self):
        return sorted(self.dict.items(), key=operator.itemgetter(1), reverse=True)

    def __str__(self):
        return ', '.join('{}:{}'.format(key, value) for key, value in self.get_sorted_dict())

    def __contains__(self, word):
        return word in self.dict

    def __iter__(self):
        return (key for key, val in self.get_sorted_dict())

    def __add__(self, other):
        result = self.dict.copy()

        for key, val in other.dict.items():
            if (key in result):
                result[key] += other.dict[key]
            else:
                result[key] = other.dict[key]

        return BagOfWords(result)

    def __getitem__(self, arg):
        return self.dict[arg]

    def __setitem__(self, arg, val):
        self.dict[arg] = val

# %%
bow = BagOfWords("ala ma kota ala ma ala")
print(bow)
# Out:
# ala:3, ma:2, kota:1

# %%
bow2 = BagOfWords(open("plik.txt"))     # tomek tez ma kota
print(bow2)
# Out:
# tomek:1, tez:1, ma:1, kota:1

# %%
#sprawdzenie czy słowo należy do worka
print(("ala" in bow) == True)
# Out:
# True

# %%
#iterowanie po słowach w worku
for word in bow:
    print(word)
# Out:
# ala
# ma
# kota

# %%
#dodawanie worków
bow3 = bow + bow2
print(("tomek" in bow) == False)
print(("tomek" in bow3) == True)
print(("ala" in bow3) == True)
print(bow3.__str__() == "ala:3, ma:3, kota:2, tomek:1, tez:1")
# Out:
# True
# True
# True
# True

# %%
#odczytywanie częstości wystąpień
print(bow["ala"] == 3)
# Out:
# True

# %%
#aktualizacja częstości wystąpień
bow3["tomek"] = 10
print(bow3["tomek"] == 10)
print(bow3)
# Out:
# True
# tomek:10, ala:3, ma:3, kota:2, tez:1
